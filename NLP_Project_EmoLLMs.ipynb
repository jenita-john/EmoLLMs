# %% [markdown]
# <a href="https://colab.research.google.com/github/jenita-john/EmoLLMs/blob/main/NLP_Project_EmoLLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lzw108/EmoLLMs.git
# Out:
# Cloning into 'EmoLLMs'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 170 (delta 58), reused 64 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (170/170), 9.18 MiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
